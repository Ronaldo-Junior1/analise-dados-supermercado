# %% [markdown]
# <a href="https://colab.research.google.com/github/Ronaldo-Junior1/analise-dados-supermercado/blob/main/Analise_base_supermercadoTeste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Dicionário das variáveis**
#
# * **Row_ID** : Identificador único de cada linha
# * **Order_ID** : Identificador único do pedido
# * **Order_Date** : Data do pedido
# * **Ship_Date** : Data de envio do pedido
# * **Ship_Mode** : Modalidade de envio escolhida
# * **Customer_ID** : Identificador único do cliente
# * **Customer_Name** : Nome do cliente
# * **Segment** : Segmento de mercado do cliente
# * **Country** : País do cliente
# * **City** : Cidade do cliente
# * **State** : Estado do cliente
# * **Postal_Code** :  Código postal
# * **Region** : Região do cliente
# * **Product_ID** : Identificador do produto
# * **Category** : Categoria do produto
# * **Sub_Category** : Subcategoria do produto
# * **Product Name** : Nome do produto
# * **Sales** : Valor de venda
# * **Quantity** : Quantidade vendida
# * **Discount** : Desconto aplicado
# * **Profit** : Lucro ou prejuízo da venda

# %%
# importar os pacotes necessarios
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme(style="whitegrid", palette='rocket')
#sns.color_palette("flare", as_cmap=True)

# %%
from google.colab import drive
drive.mount('/content/drive')

path = "/content/drive/MyDrive/Analise_dados"
# Out:
# Mounted at /content/drive

# %%
column_names = [
    'Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode' , 'Customer_ID',
    'Customer_Name', 'Segment', 'Country', 'City', 'State',
    'Postal_Code', 'Region', 'Product_ID', 'Category',
    'Sub_Category', 'Product_Name', 'Sales', 'Quantity', 'Discount',
    'Profit'
]
df = pd.read_csv(f'{path}/01_supermercados.csv', names=column_names, header=0,encoding='latin1')
df.head(10)
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 6       7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 7       8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 8       9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 9      10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 5  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 6  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 7  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 8  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 9  Brosina Hoffman   Consumer  United States      Los Angeles  ...
#
#   Postal_Code  Region       Product_ID         Category Sub_Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
# 5       90032    West  FUR-FU-10001487        Furniture  Furnishings
# 6       90032    West  OFF-AR-10002833  Office Supplies          Art
# 7       90032    West  TEC-PH-10002275       Technology       Phones
# 8       90032    West  OFF-BI-10003910  Office Supplies      Binders
# 9       90032    West  OFF-AP-10002892  Office Supplies   Appliances
#
#                                         Product_Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
# 5  Eldon Expressions Wood and Plastic Desk Access...   48.8600         7
# 6                                         Newell 322    7.2800         4
# 7                     Mitel 5320 IP Phone VoIP phone  907.1520         6
# 8  DXL Angle-View Binders with Locking Rings by S...   18.5040         3
# 9                   Belkin F5C206VTEL 6 Outlet Surge  114.9000         5
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
# 5      0.00   14.1694
# 6      0.00    1.9656
# 7      0.20   90.7152
# 8      0.20    5.7825
# 9      0.00   34.4700
#
# [10 rows x 21 columns]

# %% [markdown]
# Verificando a quantidade de entradas em nosso Dataset e quantas variáveis/colunas existem nele

# %%
#. Exibindo a quantiade de dados inseridos e a quantidade de colunas/variáveis
df.shape
# Out:
# (9994, 21)

# %% [markdown]
# Exibindo os dados estatísticos do Dataset para obter uma análise prévia dos dados

# %%
#. Exibindo os dados estatísticos do Dataset
df.describe()
# Out:
#             Row_ID   Postal_Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# *É* possível observar uma discrepância nos dados de Sales, Quantity, Discount e Profit. Onde a média dessas variáveis é, respectivamente, $229, ~3, ~15% e ~28.
# - Porém, os maiores valores são, respectivamente, ~22638, 14, 80% e ~8399. O que é estranho, tendo em vista que, respectivamente, 75% dos dados estão abaixo de ~209, 5, 20% e 29.
# - Além disso, também é possível observar que a coluna "Profit" possui tanto um extremo mínimo, ~ -6599 e um extremo positivo que é o valor máximo.

# %% [markdown]
# Verificando o tipo das variáveis para analisar se as variáveis estão com o seu tipo adequado para sua devida finalidade

# %%
#. Exibindo o tipo de cada variável
df.dtypes
# Out:
# Row_ID             int64
# Order_ID          object
# Order_Date        object
# Ship_Date         object
# Ship_Mode         object
# Customer_ID       object
# Customer_Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal_Code        int64
# Region            object
# Product_ID        object
# Category          object
# Sub_Category      object
# Product_Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %% [markdown]
# Aparentemente todas as variáveis estão com seus tipos corretos

# %%
df["Order_Date_Formatado"] = pd.to_datetime(df['Order_Date'])

# %%
df['Year'] = df['Order_Date_Formatado'].dt.year

# %%
df['Year'].unique()
# Out:
# array([2016, 2015, 2014, 2017], dtype=int32)

# %%
df['Year'].value_counts()
# Out:
# Year
# 2017    3312
# 2016    2587
# 2015    2102
# 2014    1993
# Name: count, dtype: int64

# %%
df.tail(30)
# Out:
#       Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode  \
# 9964    9965  CA-2016-146374   12/5/2016  12/10/2016    Second Class
# 9965    9966  CA-2016-146374   12/5/2016  12/10/2016    Second Class
# 9966    9967  CA-2016-146374   12/5/2016  12/10/2016    Second Class
# 9967    9968  CA-2017-153871  12/11/2017  12/17/2017  Standard Class
# 9968    9969  CA-2017-153871  12/11/2017  12/17/2017  Standard Class
# 9969    9970  CA-2017-153871  12/11/2017  12/17/2017  Standard Class
# 9970    9971  CA-2015-103772   6/28/2015    7/2/2015  Standard Class
# 9971    9972  CA-2015-103772   6/28/2015    7/2/2015  Standard Class
# 9972    9973  CA-2016-130225   9/11/2016   9/17/2016  Standard Class
# 9973    9974  US-2016-103674   12/6/2016  12/10/2016  Standard Class
# 9974    9975  US-2016-103674   12/6/2016  12/10/2016  Standard Class
# 9975    9976  US-2016-103674   12/6/2016  12/10/2016  Standard Class
# 9976    9977  US-2016-103674   12/6/2016  12/10/2016  Standard Class
# 9977    9978  US-2016-103674   12/6/2016  12/10/2016  Standard Class
# 9978    9979  US-2016-103674   12/6/2016  12/10/2016  Standard Class
# 9979    9980  US-2016-103674   12/6/2016  12/10/2016  Standard Class
# 9980    9981  US-2015-151435    9/6/2015    9/9/2015    Second Class
# 9981    9982  CA-2017-163566    8/3/2017    8/6/2017     First Class
# 9982    9983  US-2016-157728   9/22/2016   9/28/2016  Standard Class
# 9983    9984  US-2016-157728   9/22/2016   9/28/2016  Standard Class
# 9984    9985  CA-2015-100251   5/17/2015   5/23/2015  Standard Class
# 9985    9986  CA-2015-100251   5/17/2015   5/23/2015  Standard Class
# 9986    9987  CA-2016-125794   9/29/2016   10/3/2016  Standard Class
# 9987    9988  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9988    9989  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer_ID     Customer_Name      Segment        Country          City  \
# 9964    HE-14800      Harold Engle    Corporate  United States        Newark
# 9965    HE-14800      Harold Engle    Corporate  United States        Newark
# 9966    HE-14800      Harold Engle    Corporate  United States        Newark
# 9967    RB-19435   Richard Bierner     Consumer  United States    Plainfield
# 9968    RB-19435   Richard Bierner     Consumer  United States    Plainfield
# 9969    RB-19435   Richard Bierner     Consumer  United States    Plainfield
# 9970    MP-17470       Mark Packer  Home Office  United States        Smyrna
# 9971    MP-17470       Mark Packer  Home Office  United States        Smyrna
# 9972    RC-19960        Ryan Crowe     Consumer  United States       Houston
# 9973    AP-10720        Anne Pryor  Home Office  United States   Los Angeles
# 9974    AP-10720        Anne Pryor  Home Office  United States   Los Angeles
# 9975    AP-10720        Anne Pryor  Home Office  United States   Los Angeles
# 9976    AP-10720        Anne Pryor  Home Office  United States   Los Angeles
# 9977    AP-10720        Anne Pryor  Home Office  United States   Los Angeles
# 9978    AP-10720        Anne Pryor  Home Office  United States   Los Angeles
# 9979    AP-10720        Anne Pryor  Home Office  United States   Los Angeles
# 9980    SW-20455       Shaun Weien     Consumer  United States     Lafayette
# 9981    TB-21055   Ted Butterfield     Consumer  United States     Fairfield
# 9982    RC-19960        Ryan Crowe     Consumer  United States  Grand Rapids
# 9983    RC-19960        Ryan Crowe     Consumer  United States  Grand Rapids
# 9984    DV-13465  Dianna Vittorini     Consumer  United States    Long Beach
# 9985    DV-13465  Dianna Vittorini     Consumer  United States    Long Beach
# 9986    ML-17410      Maris LaWare     Consumer  United States   Los Angeles
# 9987    RA-19885      Ruben Ausman    Corporate  United States        Athens
# 9988    RA-19885      Ruben Ausman    Corporate  United States        Athens
# 9989    TB-21400  Tom Boeckenhauer     Consumer  United States         Miami
# 9990    DB-13060       Dave Brooks     Consumer  United States    Costa Mesa
# 9991    DB-13060       Dave Brooks     Consumer  United States    Costa Mesa
# 9992    DB-13060       Dave Brooks     Consumer  United States    Costa Mesa
# 9993    CC-12220      Chris Cortes     Consumer  United States   Westminster
#
#       ...       Product_ID         Category Sub_Category  \
# 9964  ...  FUR-FU-10002671        Furniture  Furnishings
# 9965  ...  OFF-PA-10000349  Office Supplies        Paper
# 9966  ...  OFF-EN-10004483  Office Supplies    Envelopes
# 9967  ...  OFF-BI-10004209  Office Supplies      Binders
# 9968  ...  OFF-BI-10004600  Office Supplies      Binders
# 9969  ...  OFF-AP-10003622  Office Supplies   Appliances
# 9970  ...  OFF-BI-10002867  Office Supplies      Binders
# 9971  ...  OFF-AR-10000538  Office Supplies          Art
# 9972  ...  OFF-EN-10000056  Office Supplies    Envelopes
# 9973  ...  TEC-PH-10004080       Technology       Phones
# 9974  ...  OFF-AR-10004752  Office Supplies          Art
# 9975  ...  OFF-PA-10000743  Office Supplies        Paper
# 9976  ...  TEC-PH-10002496       Technology       Phones
# 9977  ...  OFF-FA-10003467  Office Supplies    Fasteners
# 9978  ...  OFF-BI-10003727  Office Supplies      Binders
# 9979  ...  OFF-BI-10002026  Office Supplies      Binders
# 9980  ...  FUR-TA-10001039        Furniture       Tables
# 9981  ...  OFF-LA-10004484  Office Supplies       Labels
# 9982  ...  OFF-PA-10002195  Office Supplies        Paper
# 9983  ...  TEC-PH-10001305       Technology       Phones
# 9984  ...  OFF-LA-10003766  Office Supplies       Labels
# 9985  ...  OFF-SU-10000898  Office Supplies     Supplies
# 9986  ...  TEC-AC-10003399       Technology  Accessories
# 9987  ...  TEC-AC-10001539       Technology  Accessories
# 9988  ...  TEC-PH-10004006       Technology       Phones
# 9989  ...  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...  TEC-PH-10003645       Technology       Phones
# 9992  ...  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product_Name    Sales Quantity  \
# 9964  Electrix 20W Halogen Replacement Bulb for Zoom...   13.400        1
# 9965                                  Easy-staple paper    4.980        1
# 9966         #10 White Business Envelopes,4 1/8 x 9 1/2  109.690        7
# 9967            Fellowes Twister Kit, Gray/Clear, 3/pkg   40.200        5
# 9968          Ibico Ibimaster 300 Manual Binding System  735.980        2
# 9969  Bravo II Megaboss 12-Amp Hard Body Upright, Re...   22.750        7
# 9970            GBC Recycled Regency Composition Covers  119.560        2
# 9971  Boston Model 1800 Electric Pencil Sharpener, Gray  140.750        5
# 9972                        Cameo Buff Policy Envelopes   99.568        2
# 9973                           Avaya 5410 Digital phone  271.960        5
# 9974                               Blackstonian Pencils   18.690        7
# 9975                                         Xerox 1977   13.360        2
# 9976                                       Cisco SPA301  249.584        2
# 9977           Alliance Big Bands Rubber Bands, 12/Pack   13.860        7
# 9978  Avery Durable Slant Ring Binders With Label Ho...   13.376        4
# 9979                  Ibico Recycled Linen-Style Covers  437.472       14
# 9980                         KI Adjustable-Height Table   85.980        1
# 9981                                          Avery 476   16.520        5
# 9982  RSVP Cards & Envelopes, Blank White, 8-1/2" X ...   35.560        7
# 9983                   Panasonic KX TS208W Corded phone   97.980        2
# 9984                     Self-Adhesive Removable Labels   31.500       10
# 9985  Acme Hot Forged Carbon Steel Scissors with Nic...   55.600        4
# 9986  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...   36.240        1
# 9987  Logitech G430 Surround Sound Gaming Headset wi...   79.990        1
# 9988                    Panasonic KX - TS880B Telephone  206.100        5
# 9989                             Ultra Door Pull Handle   25.248        3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960        2
# 9991                              Aastra 57i VoIP phone  258.576        2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600        4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160        2
#
#      Discount    Profit  Order_Date_Formatado  Year
# 9964      0.0    6.4320            2016-12-05  2016
# 9965      0.0    2.3406            2016-12-05  2016
# 9966      0.0   51.5543            2016-12-05  2016
# 9967      0.0   18.0900            2017-12-11  2017
# 9968      0.0  331.1910            2017-12-11  2017
# 9969      0.0    6.5975            2017-12-11  2017
# 9970      0.0   54.9976            2015-06-28  2015
# 9971      0.0   42.2250            2015-06-28  2015
# 9972      0.2   33.6042            2016-09-11  2016
# 9973      0.2   27.1960            2016-12-06  2016
# 9974      0.0    5.2332            2016-12-06  2016
# 9975      0.0    6.4128            2016-12-06  2016
# 9976      0.2   31.1980            2016-12-06  2016
# 9977      0.0    0.0000            2016-12-06  2016
# 9978      0.2    4.6816            2016-12-06  2016
# 9979      0.2  153.1152            2016-12-06  2016
# 9980      0.0   22.3548            2015-09-06  2015
# 9981      0.2    5.3690            2017-08-03  2017
# 9982      0.0   16.7132            2016-09-22  2016
# 9983      0.0   27.4344            2016-09-22  2016
# 9984      0.0   15.1200            2015-05-17  2015
# 9985      0.0   16.1240            2015-05-17  2015
# 9986      0.0   15.2208            2016-09-29  2016
# 9987      0.0   28.7964            2017-11-17  2017
# 9988      0.0   55.6470            2017-11-17  2017
# 9989      0.2    4.1028            2014-01-21  2014
# 9990      0.0   15.6332            2017-02-26  2017
# 9991      0.2   19.3932            2017-02-26  2017
# 9992      0.0   13.3200            2017-02-26  2017
# 9993      0.0   72.9480            2017-05-04  2017
#
# [30 rows x 23 columns]

# %% [markdown]
# Verificando se o Dataset possui valores ausentes, o que pode afetar a análise dos dados

# %%
#. Exibindo os valores ausente do Datase em ordem decrescente
((df.isnull().sum() / df.shape[0])*100).sort_values(ascending=False)
# Out:
# Row_ID                  0.0
# Order_ID                0.0
# Order_Date              0.0
# Ship_Date               0.0
# Ship_Mode               0.0
# Customer_ID             0.0
# Customer_Name           0.0
# Segment                 0.0
# Country                 0.0
# City                    0.0
# State                   0.0
# Postal_Code             0.0
# Region                  0.0
# Product_ID              0.0
# Category                0.0
# Sub_Category            0.0
# Product_Name            0.0
# Sales                   0.0
# Quantity                0.0
# Discount                0.0
# Profit                  0.0
# Order_Date_Formatado    0.0
# dtype: float64

# %% [markdown]
# Não há nenhum valor ausente em nosso Dataset

# %% [markdown]
# Verificando qual o tipo de Distribuição das variáveis númericas do Dataset

# %%
#. Plotando os histogramas das variáveis numéricas
df.hist(bins=15, figsize=(20,16));

# %% [markdown]
# - A distribuição de dados para as variáveis Sales e Profit indica que há valores muito discrepantes nos dados
# - A distibuição para Discount também não é muito uniforme
# - A Distribuição para a variável Quantity tem um perfil mais normal de distribuição.

# %% [markdown]
# Verificando a margem de lucro por Produto e Segmento
#
# *   Item da lista
# *   Item da lista

# %%
#. Descobrindo a margem de lucro por produto
productProfit = df.groupby('Product_Name').Profit.mean()
print(productProfit.sort_values(ascending=False))
# Out:
# Product_Name
# Canon imageCLASS 2200 Advanced Copier                                    5039.985600
# Canon imageCLASS MF7460 Monochrome Digital Laser Multifunction Copier    1995.990000
# Ativa V4110MDD Micro-Cut Shredder                                        1886.473050
# 3D Systems Cube Printer, 2nd Generation, Magenta                         1858.985700
# Zebra ZM400 Thermal Label Printer                                        1671.768000
#                                                                             ...
# Zebra GK420t Direct Thermal/Thermal Transfer Printer                     -938.280000
# Lexmark MX611dhe Monochrome Laser Printer                               -1147.493250
# Cisco TelePresence System EX90 Videoconferencing Unit                   -1811.078400
# Cubify CubeX 3D Printer Double Head Print                               -2959.990133
# Cubify CubeX 3D Printer Triple Head Print                               -3839.990400
# Name: Profit, Length: 1850, dtype: float64

# %%
#. Descobrindo a margem de lucro por Segmento de cliente
segmentProfit = df.groupby('Segment').Profit.mean()
print(segmentProfit.sort_values(ascending=False))
# Out:
# Segment
# Home Office    33.818664
# Corporate      30.456667
# Consumer       25.836873
# Name: Profit, dtype: float64

# %%
#. Descobrindo a margem de lucro por Segmento de produto
segmentProfit = df.groupby('Category').Profit.mean()
print(segmentProfit.sort_values(ascending=False))
# Out:
# Category
# Technology         78.752002
# Office Supplies    20.327050
# Furniture           8.699327
# Name: Profit, dtype: float64

# %% [markdown]
# Agora vamos analisar a distribuição de lucro por categoria de produto.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Category', y='Profit', palette='rocket')
plt.title('Distribuição de Lucro por Categoria de Produto')
plt.xlabel('Categoria')
plt.ylabel('Lucro')
plt.show()
# Out:
# /tmp/ipykernel_9028/3330741135.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Category', y='Profit', palette='rocket')

# %% [markdown]
# Tendo isso em vista, vamos verificar quais produtos específicos dão mais prejuízo e quais dão mais lucro dentro dessas categorias.

# %%
colunas_foco = ['Category', 'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit']
maiores_lucros_cat = df.nlargest(10, 'Profit')[colunas_foco]
maiores_prejuizos_cat = df.nsmallest(10, 'Profit')[colunas_foco]

print("Maiores Prejuízos por Categoria:")
display(maiores_prejuizos_cat)

print("\nMaiores Lucros por Categoria:")
display(maiores_lucros_cat)
# Out:
# Maiores Prejuízos por Categoria:
#              Category                                       Product_Name  \
# 7772       Technology          Cubify CubeX 3D Printer Double Head Print
# 683        Technology          Cubify CubeX 3D Printer Triple Head Print
# 9774  Office Supplies          GBC DocuBind P400 Electric Binding System
# 3011       Technology          Lexmark MX611dhe Monochrome Laser Printer
# 4991  Office Supplies               Ibico EPK-21 Electric Binding System
# 3151       Technology          Cubify CubeX 3D Printer Double Head Print
# 5310  Office Supplies  Fellowes PB500 Electric Punch Plastic Comb Bin...
# 9639        Furniture  Chromcraft Bull-Nose Wood Oval Conference Tabl...
# 1199  Office Supplies          GBC DocuBind P400 Electric Binding System
# 2697       Technology  Cisco TelePresence System EX90 Videoconferenci...
#
#           Sales  Quantity  Discount     Profit
# 7772   4499.985         5       0.7 -6599.9780
# 683    7999.980         4       0.5 -3839.9904
# 9774   2177.584         8       0.8 -3701.8928
# 3011   2549.985         5       0.7 -3399.9800
# 4991   1889.990         5       0.8 -2929.4845
# 3151   1799.994         2       0.7 -2639.9912
# 5310   1525.188         6       0.8 -2287.7820
# 9639   4297.644        13       0.4 -1862.3124
# 1199   1088.792         4       0.8 -1850.9464
# 2697  22638.480         6       0.5 -1811.0784
# Maiores Lucros por Categoria:
#              Category                                       Product_Name  \
# 6826       Technology              Canon imageCLASS 2200 Advanced Copier
# 8153       Technology              Canon imageCLASS 2200 Advanced Copier
# 4190       Technology              Canon imageCLASS 2200 Advanced Copier
# 9039  Office Supplies   GBC Ibimaster 500 Manual ProClick Binding System
# 4098  Office Supplies               Ibico EPK-21 Electric Binding System
# 2623       Technology              Canon imageCLASS 2200 Advanced Copier
# 509   Office Supplies  Fellowes PB500 Electric Punch Plastic Comb Bin...
# 8488       Technology  HP Designjet T520 Inkjet Large Format Printer ...
# 7666       Technology               Hewlett Packard LaserJet 3310 Copier
# 6520  Office Supplies          GBC DocuBind P400 Electric Binding System
#
#           Sales  Quantity  Discount     Profit
# 6826  17499.950         5       0.0  8399.9760
# 8153  13999.960         4       0.0  6719.9808
# 4190  10499.970         3       0.0  5039.9856
# 9039   9892.740        13       0.0  4946.3700
# 4098   9449.950         5       0.0  4630.4755
# 2623  11199.968         4       0.2  3919.9888
# 509    6354.950         5       0.0  3177.4750
# 8488   8749.950         5       0.0  2799.9840
# 7666   5399.910         9       0.0  2591.9568
# 6520   5443.960         4       0.0  2504.2216

# %% [markdown]
# Agora, para entender o motivo desses prejuízos gigantes (como o de -6599), geralmente a causa está associada a altos descontos (Discount). Então vamos verificar se esse é um comportamento comum, onde os maiores prejuizos são nas maiores quantidades de desconto.

# %%
# Filtrando as vendas com prejuízo pior que -1000
outliers_negativos = df[df['Profit'] < -1000]

colunas_interesse = ['Product_Name', 'Segment', 'Category', 'Sales', 'Quantity', 'Discount', 'Profit']
outliers_negativos[colunas_interesse].sort_values(by='Profit').head(30)
# Out:
#                                            Product_Name      Segment  \
# 7772          Cubify CubeX 3D Printer Double Head Print     Consumer
# 683           Cubify CubeX 3D Printer Triple Head Print    Corporate
# 9774          GBC DocuBind P400 Electric Binding System     Consumer
# 3011          Lexmark MX611dhe Monochrome Laser Printer  Home Office
# 4991               Ibico EPK-21 Electric Binding System    Corporate
# 3151          Cubify CubeX 3D Printer Double Head Print     Consumer
# 5310  Fellowes PB500 Electric Punch Plastic Comb Bin...     Consumer
# 9639  Chromcraft Bull-Nose Wood Oval Conference Tabl...     Consumer
# 1199          GBC DocuBind P400 Electric Binding System     Consumer
# 2697  Cisco TelePresence System EX90 Videoconferenci...  Home Office
# 27    Riverside Palais Royal Lawyers Bookcase, Royal...     Consumer
# 3324         GBC DocuBind TL300 Electric Binding System     Consumer
# 165           Lexmark MX611dhe Monochrome Laser Printer     Consumer
# 2928          GBC DocuBind P400 Electric Binding System  Home Office
# 7898         GBC DocuBind TL300 Electric Binding System     Consumer
# 4820                Hoover Upright Vacuum With Dirt Cup     Consumer
# 2846  Fellowes PB500 Electric Punch Plastic Comb Bin...  Home Office
# 8640   GBC Ibimaster 500 Manual ProClick Binding System    Corporate
# 4355   GBC Ibimaster 500 Manual ProClick Binding System     Consumer
# 1803  Martin Yale Chadless Opener Electric Letter Op...     Consumer
# 6048         GBC DocuBind TL300 Electric Binding System    Corporate
# 5320  Chromcraft Bull-Nose Wood Oval Conference Tabl...  Home Office
#
#              Category      Sales  Quantity  Discount     Profit
# 7772       Technology   4499.985         5       0.7 -6599.9780
# 683        Technology   7999.980         4       0.5 -3839.9904
# 9774  Office Supplies   2177.584         8       0.8 -3701.8928
# 3011       Technology   2549.985         5       0.7 -3399.9800
# 4991  Office Supplies   1889.990         5       0.8 -2929.4845
# 3151       Technology   1799.994         2       0.7 -2639.9912
# 5310  Office Supplies   1525.188         6       0.8 -2287.7820
# 9639        Furniture   4297.644        13       0.4 -1862.3124
# 1199  Office Supplies   1088.792         4       0.8 -1850.9464
# 2697       Technology  22638.480         6       0.5 -1811.0784
# 27          Furniture   3083.430         7       0.5 -1665.0522
# 3324  Office Supplies    896.990         5       0.8 -1480.0335
# 165        Technology   8159.952         8       0.4 -1359.9920
# 2928  Office Supplies   1633.188         4       0.7 -1306.5504
# 7898  Office Supplies   1614.582         6       0.7 -1237.8462
# 4820  Office Supplies    463.248         8       0.8 -1181.2824
# 2846  Office Supplies    762.594         3       0.8 -1143.8910
# 8640  Office Supplies    760.980         5       0.8 -1141.4700
# 4355  Office Supplies   1598.058         7       0.7 -1065.3720
# 1803  Office Supplies   4663.736         7       0.2 -1049.3406
# 6048  Office Supplies   1345.485         5       0.7 -1031.5385
# 5320        Furniture   2314.116         7       0.4 -1002.7836

# %% [markdown]
# Dos maiores prejuízos listados, a grande maioria foi causada por descontos de 0.7 (70%) e 0.8 (80%).
#
# O maior prejuízo de todos (-6.599,97) ocorreu em uma venda de impressoras 3D com 70% de desconto.
#
# Os Binding Systemsaparecem várias vezes dando prejuízos entre -1.000 e -3.700, quase todos com 80% de desconto.
#
# O problema afeta produtos de alto valor agregado no caso tecnologia
# Dar 80% de desconto em uma caneta gera um prejuízo de centavos. Mas a tabela mostra que a empresa está dando 50% a 70% de desconto em produtos caríssimos, como Impressoras 3D, Impressoras a Laser e Sistemas de Videoconferência.
#
# A venda do sistema Cisco gerou 22.638 em receita, mas como teve 50% de desconto, resultou em um prejuízo de -1.811. Isso indica que a margem original do produto não suporta um corte de preço dessa magnitude.
#
# Quando o desconto é alto, o cliente tende a comprar mais. Veja a mesa de conferência (Chromcraft): a empresa vendeu 13 unidades com 40% de desconto. O resultado foi um prejuízo de -1.862.

# %%
# Filtrando as vendas com lucro maior que 1000
outliers_positivos = df[df['Profit'] > 1000]

outliers_positivos[colunas_interesse].sort_values(by='Profit').tail(30)
# Out:
#                                            Product_Name      Segment  \
# 994         Fellowes PB300 Plastic Comb Binding Machine    Corporate
# 6340   3D Systems Cube Printer, 2nd Generation, Magenta    Corporate
# 5126                  Ativa V4110MDD Micro-Cut Shredder     Consumer
# 515                       Canon Image Class D660 Copier  Home Office
# 353           GBC DocuBind P400 Electric Binding System  Home Office
# 4093                 Cisco 9971 IP Video Phone Charcoal     Consumer
# 5562               Hewlett Packard LaserJet 3310 Copier    Corporate
# 9270         GBC DocuBind TL300 Electric Binding System     Consumer
# 1454  Hewlett-Packard Deskjet 3050a All-in-One Color...    Corporate
# 1644                                 Canon PC940 Copier    Corporate
# 7818               Ibico EPK-21 Electric Binding System  Home Office
# 7914  Hewlett-Packard Desktjet 6988DT Refurbished Pr...  Home Office
# 7683  Fellowes PB500 Electric Punch Plastic Comb Bin...  Home Office
# 8858  Fellowes PB500 Electric Punch Plastic Comb Bin...    Corporate
# 318   Canon imageCLASS MF7460 Monochrome Digital Las...  Home Office
# 8204                  Zebra ZM400 Thermal Label Printer    Corporate
# 6626  HP Designjet T520 Inkjet Large Format Printer ...     Consumer
# 8990                 Canon PC1060 Personal Laser Copier    Corporate
# 4277   3D Systems Cube Printer, 2nd Generation, Magenta    Corporate
# 1085                  Ativa V4110MDD Micro-Cut Shredder     Consumer
# 6520          GBC DocuBind P400 Electric Binding System     Consumer
# 7666               Hewlett Packard LaserJet 3310 Copier  Home Office
# 8488  HP Designjet T520 Inkjet Large Format Printer ...     Consumer
# 509   Fellowes PB500 Electric Punch Plastic Comb Bin...     Consumer
# 2623              Canon imageCLASS 2200 Advanced Copier  Home Office
# 4098               Ibico EPK-21 Electric Binding System     Consumer
# 9039   GBC Ibimaster 500 Manual ProClick Binding System     Consumer
# 4190              Canon imageCLASS 2200 Advanced Copier     Consumer
# 8153              Canon imageCLASS 2200 Advanced Copier     Consumer
# 6826              Canon imageCLASS 2200 Advanced Copier    Corporate
#
#              Category      Sales  Quantity  Discount     Profit
# 994   Office Supplies   2715.930         7       0.0  1276.4871
# 6340       Technology   5199.960         4       0.0  1351.9896
# 5126       Technology   2799.960         4       0.0  1371.9804
# 515        Technology   2999.950         5       0.0  1379.9770
# 353   Office Supplies   4355.168         4       0.2  1415.4296
# 4093       Technology   3080.000         7       0.0  1416.8000
# 5562       Technology   2999.950         5       0.0  1439.9760
# 9270  Office Supplies   4305.552         6       0.2  1453.1238
# 1454       Technology   3040.000         8       0.0  1459.2000
# 1644       Technology   3149.930         7       0.0  1480.4671
# 7818  Office Supplies   4535.976         3       0.2  1644.2913
# 7914       Technology   3404.500         5       0.0  1668.2050
# 7683  Office Supplies   3812.970         3       0.0  1906.4850
# 8858  Office Supplies   5083.960         5       0.2  1906.4850
# 318        Technology   3991.980         2       0.0  1995.9900
# 8204       Technology   4643.800         4       0.0  2229.0240
# 6626       Technology   6999.960         4       0.0  2239.9872
# 8990       Technology   4899.930         7       0.0  2302.9671
# 4277       Technology   9099.930         7       0.0  2365.9818
# 1085       Technology   4899.930         7       0.0  2400.9657
# 6520  Office Supplies   5443.960         4       0.0  2504.2216
# 7666       Technology   5399.910         9       0.0  2591.9568
# 8488       Technology   8749.950         5       0.0  2799.9840
# 509   Office Supplies   6354.950         5       0.0  3177.4750
# 2623       Technology  11199.968         4       0.2  3919.9888
# 4098  Office Supplies   9449.950         5       0.0  4630.4755
# 9039  Office Supplies   9892.740        13       0.0  4946.3700
# 4190       Technology  10499.970         3       0.0  5039.9856
# 8153       Technology  13999.960         4       0.0  6719.9808
# 6826       Technology  17499.950         5       0.0  8399.9760

# %% [markdown]
# Dos maiores lucros listados, a esmagadora maioria foi alcançada com desconto zero (0%). O maior lucro de todos (8.399,97) ocorreu em uma venda de copiadoras avançadas com 0% de desconto e receita de 17.499.
#
# O equipamento Canon imageCLASS 2200 Advanced Copier aparece quatro vezes dominando a lista, o que prova que os produtos de alto valor agregado no segmento de Tecnologia possuem uma margem excelente quando o preço original é mantido. As informações batem perfeitamente com a análise de prejuízos, comprovando que o problema definitivamente não está nos produtos em si, mas na política agressiva de preços.
#
# Os mesmos Sistemas de Encadernação (Binding Systems) que afundaram o caixa com prejuízos de até -3.700 sob 80% de desconto, aparecem agora como os maiores lucros, gerando de 4.946, 4.630 e 2.504 quando vendidos a preço cheio.
#
# A lógica do volume também se confirma, agindo agora como um multiplicador positivo: quando o cliente compra em grande quantidade sem a aplicação de descontos altos, o retorno financeiro aumenta.
#
# O modelo GBC Ibimaster 500 exemplifica isso muito bem, com a venda de 13 unidades a 0% de desconto gerando o quarto maior lucro geral. A base mostra que a estrutura de custos da loja é sólida e os produtos são rentáveis por natureza, suportando no máximo um corte brando, já que o único desconto presente nesse top 10 foi de 20% em uma das vendas da Canon, que ainda conseguiu preservar um lucro robusto de 3.919.

# %% [markdown]
# Agora vamos analisar a distribuição de lucro por categoria de produto.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Segment', y='Profit', palette='rocket')
plt.title('Distribuição de Lucro por Segmento de Cliente')
plt.xlabel('Segmento')
plt.ylabel('Lucro')
plt.show()
# Out:
# /tmp/ipykernel_9028/3262116431.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Segment', y='Profit', palette='rocket')

# %% [markdown]
# Tendo isso em vista, vamos verificar quais produtos específicos dão mais prejuízo e quais dão mais lucro dentro dessas categorias.

# %%
colunas_foco_seg = ['Segment', 'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit']
maiores_lucros_seg = df.nlargest(10, 'Profit')[colunas_foco_seg]
maiores_prejuizos_seg = df.nsmallest(10, 'Profit')[colunas_foco_seg]

print("Maiores Prejuízos por Segmento:")
display(maiores_prejuizos_seg)

print("\nMaiores Lucros por Segmento:")
display(maiores_lucros_seg)
# Out:
# Maiores Prejuízos por Segmento:
#           Segment                                       Product_Name  \
# 7772     Consumer          Cubify CubeX 3D Printer Double Head Print
# 683     Corporate          Cubify CubeX 3D Printer Triple Head Print
# 9774     Consumer          GBC DocuBind P400 Electric Binding System
# 3011  Home Office          Lexmark MX611dhe Monochrome Laser Printer
# 4991    Corporate               Ibico EPK-21 Electric Binding System
# 3151     Consumer          Cubify CubeX 3D Printer Double Head Print
# 5310     Consumer  Fellowes PB500 Electric Punch Plastic Comb Bin...
# 9639     Consumer  Chromcraft Bull-Nose Wood Oval Conference Tabl...
# 1199     Consumer          GBC DocuBind P400 Electric Binding System
# 2697  Home Office  Cisco TelePresence System EX90 Videoconferenci...
#
#           Sales  Quantity  Discount     Profit
# 7772   4499.985         5       0.7 -6599.9780
# 683    7999.980         4       0.5 -3839.9904
# 9774   2177.584         8       0.8 -3701.8928
# 3011   2549.985         5       0.7 -3399.9800
# 4991   1889.990         5       0.8 -2929.4845
# 3151   1799.994         2       0.7 -2639.9912
# 5310   1525.188         6       0.8 -2287.7820
# 9639   4297.644        13       0.4 -1862.3124
# 1199   1088.792         4       0.8 -1850.9464
# 2697  22638.480         6       0.5 -1811.0784
# Maiores Lucros por Segmento:
#           Segment                                       Product_Name  \
# 6826    Corporate              Canon imageCLASS 2200 Advanced Copier
# 8153     Consumer              Canon imageCLASS 2200 Advanced Copier
# 4190     Consumer              Canon imageCLASS 2200 Advanced Copier
# 9039     Consumer   GBC Ibimaster 500 Manual ProClick Binding System
# 4098     Consumer               Ibico EPK-21 Electric Binding System
# 2623  Home Office              Canon imageCLASS 2200 Advanced Copier
# 509      Consumer  Fellowes PB500 Electric Punch Plastic Comb Bin...
# 8488     Consumer  HP Designjet T520 Inkjet Large Format Printer ...
# 7666  Home Office               Hewlett Packard LaserJet 3310 Copier
# 6520     Consumer          GBC DocuBind P400 Electric Binding System
#
#           Sales  Quantity  Discount     Profit
# 6826  17499.950         5       0.0  8399.9760
# 8153  13999.960         4       0.0  6719.9808
# 4190  10499.970         3       0.0  5039.9856
# 9039   9892.740        13       0.0  4946.3700
# 4098   9449.950         5       0.0  4630.4755
# 2623  11199.968         4       0.2  3919.9888
# 509    6354.950         5       0.0  3177.4750
# 8488   8749.950         5       0.0  2799.9840
# 7666   5399.910         9       0.0  2591.9568
# 6520   5443.960         4       0.0  2504.2216

# %% [markdown]
# ##Analisando as Regiões com baixa Rentabilidade

# %%
df["Year"].value_counts().sort_values(ascending=True)
# Out:
# Year
# 2014    1993
# 2015    2102
# 2016    2587
# 2017    3312
# Name: count, dtype: int64

# %%
df_2014 = df[df['Year'] == 2014]
df_2015 = df[df['Year'] == 2015]
df_2016 = df[df['Year'] == 2016]
df_2017 = df[df['Year'] == 2017]

# %%
#. Descobrindo a rentabilidade geral da Base
rentabilidade_regiao = df.groupby('Region').Profit.mean()
print(rentabilidade_regiao.sort_values(ascending=True))
# Out:
# Region
# Central    17.092709
# South      28.857673
# East       32.135808
# West       33.849032
# Name: Profit, dtype: float64

# %%
rentabilidade_regiao_anual = pd.crosstab(df["Region"], df["Year"], aggfunc = 'mean', values = df["Profit"])

print(f"Rentabilidade Geral:\n{rentabilidade_regiao.sort_values(ascending=True)}\n\n")

print(f"Rentabilidade Anual 2014:\n{rentabilidade_regiao_anual[2014].sort_values(ascending=True)}\n\n")
print(f"Rentabilidade Anual 2015:\n{rentabilidade_regiao_anual[2015].sort_values(ascending=True)}\n\n")
print(f"Rentabilidade Anual 2016:\n{rentabilidade_regiao_anual[2016].sort_values(ascending=True)}\n\n")
print(f"Rentabilidade Anual 2017:\n{rentabilidade_regiao_anual[2017].sort_values(ascending=True)}\n\n")
# Out:
# Rentabilidade Geral:
# Region
# Central    17.092709
# South      28.857673
# East       32.135808
# West       33.849032
# Name: Profit, dtype: float64
#
#
# Rentabilidade Anual 2014:
# Region
# Central     1.157840
# West       30.356568
# East       32.997310
# South      34.037593
# Name: 2014, dtype: float64
#
#
# Rentabilidade Anual 2015:
# Region
# South      24.466453
# Central    24.615130
# West       31.919306
# East       32.750020
# Name: 2015, dtype: float64
#
#
# Rentabilidade Anual 2016:
# Region
# East       26.294512
# West       29.877773
# Central    33.000270
# South      42.863943
# Name: 2016, dtype: float64
#
#
# Rentabilidade Anual 2017:
# Region
# Central     9.705455
# South      17.082834
# East       36.080957
# West       40.008179
# Name: 2017, dtype: float64

# %% [markdown]
# Podemos observar que a Região com menos rentabilidade é a região Central. Porém, precisamos saber o motivo

# %%
#. Filtrando apenas os dados referentes a região Central para um melhor estudo
df_central = df[df['Region'] == 'Central']

#. Exibindo uma parte das informações do novo DataFrame criado
df_central.head(5)
# Out:
#     Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode  \
# 14      15  US-2015-118983  11/22/2015  11/26/2015  Standard Class
# 15      16  US-2015-118983  11/22/2015  11/26/2015  Standard Class
# 16      17  CA-2014-105893  11/11/2014  11/18/2014  Standard Class
# 21      22  CA-2016-137330   12/9/2016  12/13/2016  Standard Class
# 22      23  CA-2016-137330   12/9/2016  12/13/2016  Standard Class
#
#    Customer_ID  Customer_Name      Segment        Country        City  ...  \
# 14    HP-14815  Harold Pawlan  Home Office  United States  Fort Worth  ...
# 15    HP-14815  Harold Pawlan  Home Office  United States  Fort Worth  ...
# 16    PK-19075      Pete Kriz     Consumer  United States     Madison  ...
# 21    KB-16585      Ken Black    Corporate  United States     Fremont  ...
# 22    KB-16585      Ken Black    Corporate  United States     Fremont  ...
#
#      Region       Product_ID         Category Sub_Category  \
# 14  Central  OFF-AP-10002311  Office Supplies   Appliances
# 15  Central  OFF-BI-10000756  Office Supplies      Binders
# 16  Central  OFF-ST-10004186  Office Supplies      Storage
# 21  Central  OFF-AR-10000246  Office Supplies          Art
# 22  Central  OFF-AP-10001492  Office Supplies   Appliances
#
#                                          Product_Name    Sales Quantity  \
# 14  Holmes Replacement Filter for HEPA Air Cleaner...   68.810        5
# 15   Storex DuraTech Recycled Plastic Frosted Binders    2.544        3
# 16  Stur-D-Stor Shelving, Vertical 5-Shelf: 72"H x...  665.880        6
# 21                                         Newell 318   19.460        7
# 22        Acco Six-Outlet Power Strip, 4' Cord Length   60.340        7
#
#     Discount    Profit  Order_Date_Formatado
# 14       0.8 -123.8580            2015-11-22
# 15       0.8   -3.8160            2015-11-22
# 16       0.0   13.3176            2014-11-11
# 21       0.0    5.0596            2016-12-09
# 22       0.0   15.6884            2016-12-09
#
# [5 rows x 22 columns]

# %%
#. Descobrindo a quantidade de dados para esse novo DataFrame
print(df_central.shape)
print(df[df['Year'] == 2014].shape)
print("\n")
print(df.shape)
# Out:
# (2323, 22)
# (1993, 23)
#
#
# (9994, 23)

# %% [markdown]
# - Podemos ver que é uma região com poucos dados. Caso possua muitos outliers ela será altamente influencida por esses outliers

# %%
#. Exibindo os valores estatísticos desse novo DataFrame
df_central.describe()
# Out:
#             Row_ID   Postal_Code         Sales     Quantity     Discount  \
# count  2323.000000   2323.000000   2323.000000  2323.000000  2323.000000
# mean   5030.547998  65340.572536    215.772661     3.779595     0.240353
# min      15.000000  46060.000000      0.444000     1.000000     0.000000
# 25%    2564.500000  55125.000000     14.620000     2.000000     0.000000
# 50%    5029.000000  65203.000000     45.980000     3.000000     0.200000
# 75%    7612.500000  77041.000000    200.012000     5.000000     0.300000
# max    9984.000000  79907.000000  17499.950000    14.000000     0.800000
# std    2923.638538  11427.949045    632.779010     2.160561     0.265433
#
#             Profit           Order_Date_Formatado
# count  2323.000000                           2323
# mean     17.092709  2016-04-28 19:22:17.408523520
# min   -3701.892800            2014-01-03 00:00:00
# 25%      -5.664300            2015-04-29 00:00:00
# 50%       5.184000            2016-07-22 00:00:00
# 75%      22.456200            2017-05-09 12:00:00
# max    8399.976000            2017-12-30 00:00:00
# std     291.487465                            NaN

# %% [markdown]
# - Podemos ver que ela é uma região com muitos outliers, tanto positivos quanto negativos. Vemos que a região tem um outlier negativo. Porém, um outlier muito maior positivamente o que puxa a média para cima. Além disso, 75% dos dados possuem um lucro menor que 22k e a média dessa região é 17k. Então, ainda sim parece fazer algum sentido.

# %%
df_central.hist(bins=15, figsize=(20,16));

# %% [markdown]
# - Pelo gráfico de distribuição, podemos confirmar que a região possui muitos outliers

# %%
#. Plotando um BoxPlot para verificar qual é a distribuição de lucro por Categoria de Produto

plt.figure(figsize=(10, 6))
sns.boxplot(data=df_central, x='Category', y='Profit', palette='rocket')
plt.title('Distribuição de Lucro por Categoria de Produto')
plt.xlabel('Categoria')
plt.ylabel('Lucro')
plt.show()
# Out:
# /tmp/ipykernel_9028/2474768599.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_central, x='Category', y='Profit', palette='rocket')

# %%
df_central["Category"].value_counts()
# Out:
# Category
# Office Supplies    1422
# Furniture           481
# Technology          420
# Name: count, dtype: int64

# %%
df_central[df_central["Profit"] < 0]["Category"].value_counts()
# Out:
# Category
# Office Supplies    375
# Furniture          317
# Technology          49
# Name: count, dtype: int64

# %%
df_central[df_central["Profit"] > 0]["Category"].value_counts()
# Out:
# Category
# Office Supplies    1044
# Technology          370
# Furniture           157
# Name: count, dtype: int64

# %%
df_central[df_central["Profit"] == 0]["Category"].value_counts()
# Out:
# Category
# Furniture          7
# Office Supplies    3
# Technology         1
# Name: count, dtype: int64

# %%
rentabilidade_categoria_produtos_central = df_central.groupby('Category').Profit.sum()
print(rentabilidade_categoria_produtos_central.sort_values(ascending=True))
# Out:
# Category
# Furniture          -2871.0494
# Office Supplies     8879.9799
# Technology         33697.4320
# Name: Profit, dtype: float64

# %% [markdown]
# - Podemos ver que a região possui muito prejuízo por conta dos produtos de Furniture, onde quase todos deram prejuízo

# %%
(df_central["Profit"] < 0).value_counts()
# Out:
# Profit
# False    1582
# True      741
# Name: count, dtype: int64

# %% [markdown]
# - Podemos ver que a região possui mais resultados positivos do que negativos. O que pode estar abaixando o rendimento da região seriam os outliers Negativos

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_central, x='State', y='Profit', palette='rocket')
plt.title('Distribuição de Lucro por Estado da Região')
plt.xlabel('Estado')
plt.ylabel('Lucro')
plt.show()
# Out:
# /tmp/ipykernel_9028/382517745.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_central, x='State', y='Profit', palette='rocket')

# %% [markdown]
# - Podemos ver que a região possui os dois estados que estão entre os que mais dão prejuízo no DataSet
# - Agora, vamos ver se sem os outliers a interpretação fica a mesma

# %%
#. Plotando um BoxPlot para verificar qual é a distribuição de lucro por Categoria de Produto sem OutLiers

plt.figure(figsize=(10, 6))
sns.boxplot(data=df_central, x='Category', y='Profit', palette='rocket', showfliers=False)
plt.title('Distribuição de Lucro por Categoria de Produto')
plt.xlabel('Categoria')
plt.ylabel('Lucro')
plt.show()
# Out:
# /tmp/ipykernel_9028/1702846400.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_central, x='Category', y='Profit', palette='rocket', showfliers=False)

# %% [markdown]
# - Aqui conseguimos confirmar que realmente a categoria Furniture está dando prejuízo para essa região. Já que, a mediana está abaixo de zero, ou seja, 50% das vendas dessa categoria nessa região dá prejuízo.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_central, x='State', y='Profit', palette='rocket', showfliers = False)
plt.title('Distribuição de Lucro por Estado da Região')
plt.xlabel('Estado')
plt.ylabel('Lucro')
plt.show()
# Out:
# /tmp/ipykernel_9028/1013078874.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_central, x='State', y='Profit', palette='rocket', showfliers = False)

# %% [markdown]
# Aqui podemos ver que o estado de Texas e illinois ainda se mantém como os dois estados que mais dão prejuízos para essa região. Porém, não aparenta ser o suficiente para diexar a média da região tão baixa.

# %% [markdown]
# - Analisando a região South

# %%
#. Filtrando apenas os dados referentes a região South para um melhor estudo
df_south = df[df['Region'] == 'South']

#. Exibindo uma parte das informações do novo DataFrame criado
df_south.head(5)
# Out:
#     Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode  \
# 0        1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1        2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 3        4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4        5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 12      13  CA-2017-114412   4/15/2017   4/20/2017  Standard Class
#
#    Customer_ID   Customer_Name   Segment        Country             City  ...  \
# 0     CG-12520     Claire Gute  Consumer  United States        Henderson  ...
# 1     CG-12520     Claire Gute  Consumer  United States        Henderson  ...
# 3     SO-20335  Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...
# 4     SO-20335  Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...
# 12    AA-10480    Andrew Allen  Consumer  United States          Concord  ...
#
#    Region       Product_ID         Category Sub_Category  \
# 0   South  FUR-BO-10001798        Furniture    Bookcases
# 1   South  FUR-CH-10000454        Furniture       Chairs
# 3   South  FUR-TA-10000577        Furniture       Tables
# 4   South  OFF-ST-10000760  Office Supplies      Storage
# 12  South  OFF-PA-10002365  Office Supplies        Paper
#
#                                          Product_Name     Sales Quantity  \
# 0                   Bush Somerset Collection Bookcase  261.9600        2
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 3       Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                      Eldon Fold 'N Roll Cart System   22.3680        2
# 12                                         Xerox 1967   15.5520        3
#
#     Discount    Profit  Order_Date_Formatado
# 0       0.00   41.9136            2016-11-08
# 1       0.00  219.5820            2016-11-08
# 3       0.45 -383.0310            2015-10-11
# 4       0.20    2.5164            2015-10-11
# 12      0.20    5.4432            2017-04-15
#
# [5 rows x 22 columns]

# %%
#. Descobrindo a quantidade de dados para esse novo DataFrame
print(df_south.shape)
# Out:
# (1620, 22)

# %% [markdown]
# - Nessa região também temos poucos dados, que serão impactados caso exista muitos outliers

# %%
#. Exibindo os valores estatísticos desse novo DataFrame
df_south.describe()
# Out:
#             Row_ID   Postal_Code         Sales     Quantity     Discount  \
# count  1620.000000   1620.000000   1620.000000  1620.000000  1620.000000
# mean   5069.935185  34490.772840    241.803645     3.832716     0.147253
# min       1.000000  22153.000000      1.167000     1.000000     0.000000
# 25%    2702.750000  28380.750000     17.187000     2.000000     0.000000
# 50%    5075.000000  32718.500000     54.594000     3.000000     0.200000
# 75%    7489.500000  37211.000000    208.722000     5.000000     0.200000
# max    9990.000000  72762.000000  22638.480000    14.000000     0.700000
# std    2791.096956  11000.257422    774.796273     2.249379     0.197420
#
#             Profit           Order_Date_Formatado
# count  1620.000000                           1620
# mean     28.857673  2016-04-03 19:13:46.666666752
# min   -3839.990400            2014-01-06 00:00:00
# 25%       1.947100            2015-04-21 00:00:00
# 50%       9.072000            2016-05-18 00:00:00
# 75%      34.233925            2017-05-05 06:00:00
# max    3177.475000            2017-12-29 00:00:00
# std     212.893088                            NaN

# %% [markdown]
# - Nessa região podemos ver que ela também temos outliers positivos e negativos

# %%
df_south.hist(bins=15, figsize=(20,16));

# %%
#. Plotando um BoxPlot para verificar qual é a distribuição de lucro por Categoria de Produto

plt.figure(figsize=(10, 6))
sns.boxplot(data=df_south, x='Category', y='Profit', palette='rocket')
plt.title('Distribuição de Lucro por Categoria de Produto')
plt.xlabel('Categoria')
plt.ylabel('Lucro')
plt.show()
# Out:
# /tmp/ipykernel_9028/1933356045.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_south, x='Category', y='Profit', palette='rocket')

# %%
#. Descobrindo quntas vendas por categoria de produtos foram feitas nessa região
df_south["Category"].value_counts()
# Out:
# Category
# Office Supplies    995
# Furniture          332
# Technology         293
# Name: count, dtype: int64

# %%
df_south[df_south["Profit"] < 0]["Category"].value_counts()
# Out:
# Category
# Office Supplies    170
# Furniture           58
# Technology          31
# Name: count, dtype: int64

# %% [markdown]
# - Podemos ver que pouquíssimas vendas resultaram em prejuízo

# %%
df_south[df_south["Profit"] == 0]["Category"].value_counts()
# Out:
# Category
# Furniture          7
# Office Supplies    4
# Technology         2
# Name: count, dtype: int64

# %% [markdown]
# - Quase nenhuma venda deixou de dar lucro

# %%
df_south[df_south["Profit"] > 0]["Category"].value_counts()
# Out:
# Category
# Office Supplies    821
# Furniture          267
# Technology         260
# Name: count, dtype: int64

# %% [markdown]
# - A maioria das vendas resultaram em lucro

# %%
rentabilidade_categoria_produtos_south = df_south.groupby('Category').Profit.sum()
print(rentabilidade_categoria_produtos_south.sort_values(ascending=True))
# Out:
# Category
# Furniture           6771.2061
# Office Supplies    19986.3928
# Technology         19991.8314
# Name: Profit, dtype: float64

# %% [markdown]
# - Se pegarmos o total da região. Podemos ver que todas as suas categorias de produtos fecharam no lucro

# %%
(df_south["Profit"] < 0).value_counts()
# Out:
# Profit
# False    1361
# True      259
# Name: count, dtype: int64

# %% [markdown]
# - Apenas ~200 vendas resultaram em prejuízo

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_south, x='State', y='Profit', palette='rocket')
plt.title('Distribuição de Lucro por Estado da Região')
plt.xlabel('Estado')
plt.ylabel('Lucro')
plt.show()
# Out:
# /tmp/ipykernel_9028/3239884011.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_south, x='State', y='Profit', palette='rocket')

# %% [markdown]
# - Podemos ver que alguns Estados estão dando o maior prejuízo da região como Florida, North Carolina e Tennessee

# %% [markdown]
# - Agora vamos visualizar os dados sem outliers para verificar se a interpretação permanece a mesma

# %%
#. Plotando um BoxPlot para verificar qual é a distribuição de lucro por Categoria de Produto sem OutLiers

plt.figure(figsize=(10, 6))
sns.boxplot(data=df_south, x='Category', y='Profit', palette='rocket', showfliers=False)
plt.title('Distribuição de Lucro por Categoria de Produto')
plt.xlabel('Categoria')
plt.ylabel('Lucro')
plt.show()
# Out:
# /tmp/ipykernel_9028/1199552242.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_south, x='Category', y='Profit', palette='rocket', showfliers=False)

# %% [markdown]
# - Aqui podemos ver que a região está relativamente bem no sentido de Rentabilidade. Já que, em todas as categorias a mediana está acima de 0. Isso pode ser resultado da baixa quantidade de dados presentes nela, ou seja, poucos dados e desses poucos dados aparecem muitos dados positivos.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_south, x='State', y='Profit', palette='rocket', showfliers = False)
plt.title('Distribuição de Lucro por Estado da Região')
plt.xlabel('Estado')
plt.ylabel('Lucro')
plt.show()
# Out:
# /tmp/ipykernel_9028/3181815378.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_south, x='State', y='Profit', palette='rocket', showfliers = False)

# %% [markdown]
# - Quando tiramos os outliers as coisas mudam, agora os prejuízos dos Estados menos rentáveis não tão altos quanto visto anteriormente

# %% [markdown]
# ##Analisando clientes com baixa rentabilidade

# %%
rentabilidade_clientes = df.groupby('Customer_Name').Profit.mean()
print(rentabilidade_clientes.sort_values(ascending=True))
# Out:
# Customer_Name
# Cindy Stewart          -736.265500
# Grant Thornton         -684.776483
# Sharelle Roach         -370.434933
# Paul Knutson           -266.235000
# Jim Radford            -261.721500
#                            ...
# Christopher Martinez    389.989040
# Tom Ashbrook            470.378830
# Hunter Lopez            511.129927
# Mitch Willingham        555.172000
# Tamara Chand            748.443658
# Name: Profit, Length: 793, dtype: float64

# %% [markdown]
# - Podemos ver que o clientes com menos rentabilidade são: Cindy Stewart e Grant Thornton

# %%
#. Filtrando apenas os dados referentes ao cliente Cindy Stewart para um melhor estudo
df_Cindy = df[df['Customer_Name'] == 'Cindy Stewart']

#. Exibindo uma parte das informações do novo DataFrame criado
df_Cindy.head(5)
# Out:
#       Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode  \
# 1477    1478  CA-2016-121958  11/13/2016  11/17/2016  Standard Class
# 1507    1508  CA-2016-134208   9/17/2016   9/23/2016  Standard Class
# 2803    2804  CA-2015-159380   5/12/2015   5/16/2015  Standard Class
# 2804    2805  CA-2015-159380   5/12/2015   5/16/2015  Standard Class
# 6822    6823  US-2017-115609   11/2/2017   11/7/2017  Standard Class
#
#      Customer_ID  Customer_Name   Segment        Country           City  ...  \
# 1477    CS-12505  Cindy Stewart  Consumer  United States    Thomasville  ...
# 1507    CS-12505  Cindy Stewart  Consumer  United States       Columbus  ...
# 2803    CS-12505  Cindy Stewart  Consumer  United States  San Francisco  ...
# 2804    CS-12505  Cindy Stewart  Consumer  United States  San Francisco  ...
# 6822    CS-12505  Cindy Stewart  Consumer  United States    Los Angeles  ...
#
#      Region       Product_ID         Category Sub_Category  \
# 1477  South  OFF-SU-10000381  Office Supplies     Supplies
# 1507  South  TEC-MA-10004458       Technology     Machines
# 2803   West  OFF-PA-10003893  Office Supplies        Paper
# 2804   West  OFF-PA-10004239  Office Supplies        Paper
# 6822   West  OFF-AP-10003040  Office Supplies   Appliances
#
#                                            Product_Name    Sales Quantity  \
# 1477  Acme Forged Steel Scissors with Black Enamel H...   52.136        7
# 1507  Lexmark X 9575 Professional All-in-One Color P...  396.000        4
# 2803                                         Xerox 1962   12.840        3
# 2804                                         Xerox 1953   25.680        6
# 6822  Fellowes 8 Outlet Superior Workstation Surge P...  168.100        5
#
#       Discount    Profit  Order_Date_Formatado
# 1477       0.2    5.8653            2016-11-13
# 1507       0.0  190.0800            2016-09-17
# 2803       0.0    5.7780            2015-05-12
# 2804       0.0   11.5560            2015-05-12
# 6822       0.0   43.7060            2017-11-02
#
# [5 rows x 22 columns]

# %%
#. Filtrando apenas os dados referentes ao cliente Grant Thornton para um melhor estudo
df_Grant = df[df['Customer_Name'] == 'Grant Thornton']

#. Exibindo uma parte das informações do novo DataFrame criado
df_Grant.head(5)
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 683      684  US-2017-168116  11/4/2017  11/4/2017        Same Day
# 684      685  US-2017-168116  11/4/2017  11/4/2017        Same Day
# 2139    2140  CA-2014-159520   6/6/2014  6/11/2014  Standard Class
# 2140    2141  CA-2014-159520   6/6/2014  6/11/2014  Standard Class
# 2141    2142  CA-2014-159520   6/6/2014  6/11/2014  Standard Class
#
#      Customer_ID   Customer_Name    Segment        Country        City  ...  \
# 683     GT-14635  Grant Thornton  Corporate  United States  Burlington  ...
# 684     GT-14635  Grant Thornton  Corporate  United States  Burlington  ...
# 2139    GT-14635  Grant Thornton  Corporate  United States  Long Beach  ...
# 2140    GT-14635  Grant Thornton  Corporate  United States  Long Beach  ...
# 2141    GT-14635  Grant Thornton  Corporate  United States  Long Beach  ...
#
#      Region       Product_ID         Category Sub_Category  \
# 683   South  TEC-MA-10004125       Technology     Machines
# 684   South  OFF-AP-10002457  Office Supplies   Appliances
# 2139   East  OFF-BI-10003982  Office Supplies      Binders
# 2140   East  OFF-SU-10001664  Office Supplies     Supplies
# 2141   East  FUR-TA-10003238        Furniture       Tables
#
#                                            Product_Name     Sales Quantity  \
# 683           Cubify CubeX 3D Printer Triple Head Print  7999.980        4
# 684   Eureka The Boss Plus 12-Amp Hard Box Upright V...   167.440        2
# 2139   Wilson Jones Century Plastic Molded Ring Binders   149.544        9
# 2140  Acme Office Executive Series Stainless Steel T...    17.140        2
# 2141  Chromcraft Bull-Nose Wood 48" x 96" Rectangula...   991.764        3
#
#       Discount     Profit  Order_Date_Formatado
# 683        0.5 -3839.9904            2017-11-04
# 684        0.2    14.6510            2017-11-04
# 2139       0.2    50.4711            2014-06-06
# 2140       0.0     4.4564            2014-06-06
# 2141       0.4  -347.1174            2014-06-06
#
# [5 rows x 22 columns]

# %%
#. Descobrindo a quantidade de dados que o nosso cliente Cindy possui
df_Cindy.shape
# Out:
# (9, 22)

# %%
#. Descobrindo a quantidade de dados que o nosso cliente Grant possui
df_Grant.shape
# Out:
# (6, 22)

# %%
#. Exibindo os dados estatísticos do cliente Cindy para uma análise prévia
df_Cindy.describe()
# Out:
#             Row_ID   Postal_Code        Sales  Quantity  Discount  \
# count     9.000000      9.000000     9.000000  9.000000  9.000000
# mean   5377.444444  62078.222222   632.228333  4.444444  0.200000
# min    1478.000000  27360.000000    12.840000  2.000000  0.000000
# 25%    2804.000000  43130.000000    25.680000  3.000000  0.000000
# 50%    6823.000000  43130.000000    59.976000  5.000000  0.000000
# 75%    7773.000000  91767.000000   396.000000  5.000000  0.200000
# max    9660.000000  94122.000000  4499.985000  7.000000  0.700000
# std    3183.243790  29388.414455  1460.029469  1.589899  0.295804
#
#             Profit Order_Date_Formatado
# count     9.000000                    9
# mean   -736.265500  2016-05-04 13:20:00
# min   -6599.978000  2014-03-26 00:00:00
# 25%       5.778000  2015-05-12 00:00:00
# 50%       9.000000  2016-11-13 00:00:00
# 75%      11.995200  2016-11-25 00:00:00
# max     190.080000  2017-11-02 00:00:00
# std    2202.613475                  NaN

# %%
#. Exibindo os dados estatísticos do cliente Grant para uma análise prévia
df_Grant.describe()
# Out:
#             Row_ID   Postal_Code        Sales  Quantity  Discount  \
# count     6.000000      6.000000     6.000000  6.000000  6.000000
# mean   1850.333333  16521.000000  1558.535333  4.333333  0.250000
# min     684.000000  10009.000000    17.140000  2.000000  0.000000
# 25%    1048.750000  11561.000000    56.394000  2.250000  0.200000
# 50%    2140.500000  11561.000000   158.492000  3.500000  0.200000
# 75%    2141.750000  23303.000000   785.683000  5.500000  0.350000
# max    3310.000000  27217.000000  7999.980000  9.000000  0.500000
# std    1010.190609   8306.861935  3176.803966  2.732520  0.176068
#
#             Profit Order_Date_Formatado
# count     6.000000                    6
# mean   -684.776483  2015-10-20 20:00:00
# min   -3839.990400  2014-06-06 00:00:00
# 25%    -259.223950  2014-06-06 00:00:00
# 50%       6.663400  2015-02-19 12:00:00
# 75%      13.205850  2017-05-05 12:00:00
# max      50.471100  2017-11-04 00:00:00
# std    1552.762976                  NaN
